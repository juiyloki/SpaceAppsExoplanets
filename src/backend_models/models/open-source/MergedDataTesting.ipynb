# %% [markdown]
# With the merged data, now we'll try some typical models for our ML

# %%
from sklearn.metrics import make_scorer, precision_score, f1_score, recall_score
from sklearn.model_selection import GroupKFold, RandomizedSearchCV
import pandas as pd
from sklearn.ensemble import RandomForestClassifier

X_train = pd.read_csv("../../datasets/merged/X_train_imputed_scaled.csv", index_col=0)
X_test = pd.read_csv("../../datasets/merged/X_test_imputed_scaled.csv",  index_col=0)
y_train = pd.read_csv("../../datasets/merged/y_train.csv", index_col=0)["label"]
y_test = pd.read_csv("../../datasets/merged/y_test.csv",  index_col=0)["label"]
groups = pd.read_csv("../../datasets/merged/groups.csv", index_col=0)["star_key"]

param_grid = {
    'n_estimators': [100, 150, 200, 300],
    'max_depth': [None, 10],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2],
    'max_features': ['sqrt', 'log2'],
    'criterion': ['gini', 'entropy']
}

rf = RandomForestClassifier(random_state=42)

kf = GroupKFold(n_splits=5)

scoring = {
    "f1": make_scorer(f1_score, pos_label= 1),
    "precision": make_scorer(precision_score, pos_label= 1),
    "recall": make_scorer(recall_score, pos_label=1),
    "precisionF" : make_scorer(precision_score, pos_label=0),
}

search_rf = RandomizedSearchCV(
    rf,
    param_distributions=param_grid,
    n_iter=50,
    cv=kf,
    n_jobs=-1,
    random_state=42,
    verbose=2,
    scoring=scoring,
    refit='precision'
)


search_rf.fit(X_train, y_train, groups=groups)
print(search_rf.best_params_)
optimal_rf = search_rf.best_estimator_
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   2.0s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   2.0s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   2.0s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.4s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.4s
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   4.6s
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   4.7s
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   4.8s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.6s
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   4.9s
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   4.9s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.5s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.6s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.6s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.6s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   4.0s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   4.1s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   4.0s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   4.0s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   3.8s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   4.1s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   2.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   2.0s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   4.1s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   4.2s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   1.9s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   2.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   1.8s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   4.2s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   4.2s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.3s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.3s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.6s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.7s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.4s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.5s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.6s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.7s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.6s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.7s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   4.2s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   4.3s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   3.3s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   3.2s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   4.2s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   3.4s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   4.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   4.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.9s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   2.0s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   2.0s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   2.1s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.9s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   3.8s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   3.9s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   4.4s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.7s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.4s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.4s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   4.1s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   4.1s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   4.2s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   4.1s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.4s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.5s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.5s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.5s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.5s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.5s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.7s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.7s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.7s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.7s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.7s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.7s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.7s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.8s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.8s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.8s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   1.2s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   2.8s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   2.9s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   2.8s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   3.0s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   3.0s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=150; total time=   3.1s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=150; total time=   2.8s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=150; total time=   2.8s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=150; total time=   2.8s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=150; total time=   2.7s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.8s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.8s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.8s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.8s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.8s
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.7s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   4.2s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   4.1s
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.7s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   4.2s
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.7s
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   3.9s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.3s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.3s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   3.8s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.7s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.7s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.7s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.7s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.6s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.7s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.6s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.7s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.7s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=150; total time=   2.3s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=150; total time=   2.4s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=150; total time=   2.4s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.3s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=150; total time=   2.4s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=150; total time=   2.5s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.4s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.4s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.4s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.4s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.4s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.4s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.4s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.3s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.2s
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.7s
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.7s
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.7s
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.7s
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.7s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   3.2s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   3.2s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   3.2s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   3.2s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   3.3s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=150; total time=   1.9s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=150; total time=   1.9s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=150; total time=   1.8s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=150; total time=   1.8s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=150; total time=   2.0s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   3.2s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   3.4s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   3.4s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   3.5s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   3.4s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   3.9s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   4.1s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   4.1s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   2.2s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   2.2s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   2.2s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   2.0s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   3.4s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   3.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   2.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.8s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   3.3s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   3.2s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   3.3s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   3.3s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   3.3s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=150; total time=   2.7s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=150; total time=   2.4s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=150; total time=   2.6s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   2.1s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   1.9s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=150; total time=   2.4s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   2.1s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=150; total time=   2.4s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.7s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   2.0s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   2.0s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.4s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.7s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.6s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.7s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.7s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.3s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.5s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.6s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.7s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.3s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.3s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   2.1s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   2.1s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   2.1s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   2.2s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   2.1s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.0s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.7s
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.9s
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.9s
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.9s
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.8s
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.8s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.7s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   4.9s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   4.9s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   4.9s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   3.8s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   3.9s
# {'n_estimators': 300, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'gini'}

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Wyniki z grid searcha
results = pd.DataFrame(search_rf.cv_results_)  # search = RandomizedSearchCV

# Wybieramy kolumnę parametru, który chcemy analizować (np. n_estimators)
# Dla pipeline byłoby "param_classifier__n_estimators", ale u Ciebie raczej sam model:
results = results.set_index("param_n_estimators")

# Wybieramy metryki, które nas interesują
metrics = ["mean_test_f1", "mean_test_precision", "mean_test_recall", "mean_test_precisionF"]

# Tworzymy podzbiór danych
plot_data = results.groupby("param_n_estimators")[metrics].mean()

# --- Rysowanie wykresu ---
plt.figure(figsize=(10, 5))
for metric in metrics:
    plt.plot(plot_data.index, plot_data[metric], marker='o', label=metric)

plt.xlabel("n_estimators")
plt.ylabel("Score")
plt.title("Metryki vs liczba drzew w RandomForestClassifier")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Now we will try SVC

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
svc = SVC(probability=True)

param_grid = {
    "C": [0.1, 1, 10, 100, 500, 1000,],
    "kernel": ["linear", "rbf"],
    "gamma": ["scale", "auto"],  # tylko dla rbf
    "degree": [2, 3, 4],         # tylko dla poly / linear, dla rbf nie używa się
}

search_svc = RandomizedSearchCV(
    estimator=svc,
    param_distributions=param_grid,
    n_iter=20,           # losowe kombinacje
    cv=5,
    n_jobs=-1,
    verbose=2,
    random_state=42,
    scoring=scoring,
    refit="f1"
)

search_svc.fit(X_train, y_train)

print("Najlepsze parametry SVC:", search_svc.best_params_)
optimal_svc = search_svc.best_estimator_
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV] END ........C=0.1, degree=3, gamma=scale, kernel=linear; total time=   4.5s
# [CV] END ........C=0.1, degree=3, gamma=scale, kernel=linear; total time=   4.8s
# [CV] END ........C=0.1, degree=3, gamma=scale, kernel=linear; total time=   4.8s
# [CV] END ........C=0.1, degree=3, gamma=scale, kernel=linear; total time=   5.0s
# [CV] END ........C=0.1, degree=3, gamma=scale, kernel=linear; total time=   5.3s
# [CV] END ...........C=1, degree=3, gamma=auto, kernel=linear; total time=   6.3s
# [CV] END ...........C=1, degree=3, gamma=auto, kernel=linear; total time=   6.1s
# [CV] END ...........C=1, degree=3, gamma=auto, kernel=linear; total time=   6.9s
# [CV] END ........C=0.1, degree=2, gamma=scale, kernel=linear; total time=   4.8s
# [CV] END ...........C=1, degree=3, gamma=auto, kernel=linear; total time=   6.2s
# [CV] END ...........C=1, degree=3, gamma=auto, kernel=linear; total time=   6.1s
# [CV] END ........C=0.1, degree=2, gamma=scale, kernel=linear; total time=   4.5s
# [CV] END ........C=0.1, degree=2, gamma=scale, kernel=linear; total time=   4.4s
# [CV] END ........C=0.1, degree=2, gamma=scale, kernel=linear; total time=   4.7s
# [CV] END ........C=0.1, degree=2, gamma=scale, kernel=linear; total time=   5.0s
# [CV] END .........C=10, degree=3, gamma=scale, kernel=linear; total time=  12.7s
# [CV] END .........C=10, degree=3, gamma=scale, kernel=linear; total time=  13.7s
# [CV] END .........C=10, degree=3, gamma=scale, kernel=linear; total time=  11.9s
# [CV] END .........C=10, degree=3, gamma=scale, kernel=linear; total time=  12.0s
# [CV] END .........C=10, degree=3, gamma=scale, kernel=linear; total time=  13.3s
# [CV] END .........C=500, degree=2, gamma=auto, kernel=linear; total time= 2.2min
# [CV] END .........C=500, degree=2, gamma=auto, kernel=linear; total time= 2.6min
# [CV] END .........C=500, degree=2, gamma=auto, kernel=linear; total time= 2.5min
# [CV] END .........C=0.1, degree=4, gamma=auto, kernel=linear; total time=   4.9s
# [CV] END .........C=0.1, degree=4, gamma=auto, kernel=linear; total time=   4.4s
# [CV] END .........C=0.1, degree=4, gamma=auto, kernel=linear; total time=   4.3s
# [CV] END .........C=0.1, degree=4, gamma=auto, kernel=linear; total time=   5.9s
# [CV] END .........C=0.1, degree=4, gamma=auto, kernel=linear; total time=   5.2s
# [CV] END ........C=1000, degree=2, gamma=auto, kernel=linear; total time= 3.8min
# [CV] END ........C=1000, degree=2, gamma=auto, kernel=linear; total time= 4.0min
# [CV] END ..........C=10, degree=4, gamma=auto, kernel=linear; total time=  17.3s
# [CV] END ........C=1000, degree=2, gamma=auto, kernel=linear; total time= 3.9min
# [CV] END ..........C=10, degree=4, gamma=auto, kernel=linear; total time=  15.5s
# [CV] END ..........C=10, degree=4, gamma=auto, kernel=linear; total time=  14.3s
# [CV] END ..........C=1, degree=2, gamma=scale, kernel=linear; total time=   7.9s
# [CV] END ..........C=10, degree=4, gamma=auto, kernel=linear; total time=  14.3s
# [CV] END ..........C=10, degree=4, gamma=auto, kernel=linear; total time=  15.4s
# [CV] END ..........C=1, degree=2, gamma=scale, kernel=linear; total time=   8.5s
# [CV] END ..........C=1, degree=2, gamma=scale, kernel=linear; total time=   8.1s
# [CV] END ..........C=1, degree=2, gamma=scale, kernel=linear; total time=   8.3s
# [CV] END ..........C=1, degree=2, gamma=scale, kernel=linear; total time=   8.0s
# [CV] END ........C=1000, degree=2, gamma=auto, kernel=linear; total time= 4.7min
# [CV] END ........C=1000, degree=2, gamma=auto, kernel=linear; total time= 4.9min
# [CV] END ............C=100, degree=4, gamma=auto, kernel=rbf; total time=  11.1s
# [CV] END ............C=100, degree=4, gamma=auto, kernel=rbf; total time=  10.4s
# [CV] END .........C=500, degree=2, gamma=auto, kernel=linear; total time= 2.3min
# [CV] END ............C=100, degree=4, gamma=auto, kernel=rbf; total time=   9.6s
# [CV] END ............C=100, degree=4, gamma=auto, kernel=rbf; total time=  11.7s
# [CV] END ............C=100, degree=4, gamma=auto, kernel=rbf; total time=  11.1s
# [CV] END .........C=500, degree=2, gamma=auto, kernel=linear; total time= 2.4min
# [CV] END .............C=10, degree=3, gamma=auto, kernel=rbf; total time=   8.6s
# [CV] END .............C=10, degree=3, gamma=auto, kernel=rbf; total time=   8.5s
# [CV] END .............C=10, degree=3, gamma=auto, kernel=rbf; total time=   7.9s
# [CV] END .............C=10, degree=3, gamma=auto, kernel=rbf; total time=   8.7s
# [CV] END .............C=10, degree=3, gamma=auto, kernel=rbf; total time=   8.7s
# [CV] END ...........C=0.1, degree=4, gamma=scale, kernel=rbf; total time=   9.0s
# [CV] END ...........C=0.1, degree=4, gamma=scale, kernel=rbf; total time=   8.9s
# [CV] END ...........C=0.1, degree=4, gamma=scale, kernel=rbf; total time=   8.2s
# [CV] END ...........C=0.1, degree=4, gamma=scale, kernel=rbf; total time=   8.7s
# [CV] END ...........C=0.1, degree=4, gamma=scale, kernel=rbf; total time=   8.7s
# [CV] END ...........C=100, degree=4, gamma=scale, kernel=rbf; total time=  10.2s
# [CV] END ...........C=100, degree=4, gamma=scale, kernel=rbf; total time=  10.8s
# [CV] END ...........C=100, degree=4, gamma=scale, kernel=rbf; total time=   9.4s
# [CV] END ...........C=100, degree=4, gamma=scale, kernel=rbf; total time=  10.9s
# [CV] END ...........C=100, degree=4, gamma=scale, kernel=rbf; total time=   9.6s
# [CV] END ...........C=0.1, degree=3, gamma=scale, kernel=rbf; total time=   9.0s
# [CV] END ...........C=0.1, degree=3, gamma=scale, kernel=rbf; total time=   9.1s
# [CV] END ...........C=0.1, degree=3, gamma=scale, kernel=rbf; total time=   9.0s
# [CV] END ...........C=0.1, degree=3, gamma=scale, kernel=rbf; total time=   9.0s
# [CV] END .........C=500, degree=3, gamma=auto, kernel=linear; total time= 2.3min
# [CV] END ...........C=1, degree=4, gamma=auto, kernel=linear; total time=   7.6s
# [CV] END ...........C=0.1, degree=3, gamma=scale, kernel=rbf; total time=   9.1s
# [CV] END ...........C=1, degree=4, gamma=auto, kernel=linear; total time=   7.3s
# [CV] END .........C=500, degree=3, gamma=auto, kernel=linear; total time= 2.4min
# [CV] END ...........C=1, degree=4, gamma=auto, kernel=linear; total time=   6.6s
# [CV] END ...........C=1, degree=4, gamma=auto, kernel=linear; total time=   6.8s
# [CV] END ...........C=1, degree=4, gamma=auto, kernel=linear; total time=   6.8s
# [CV] END .........C=500, degree=3, gamma=auto, kernel=linear; total time= 2.3min
# [CV] END .........C=500, degree=3, gamma=auto, kernel=linear; total time= 2.7min
# [CV] END .........C=500, degree=3, gamma=auto, kernel=linear; total time= 2.8min
# [CV] END ...........C=500, degree=2, gamma=scale, kernel=rbf; total time=  17.7s
# [CV] END ...........C=500, degree=2, gamma=scale, kernel=rbf; total time=  18.8s
# [CV] END ...........C=500, degree=2, gamma=scale, kernel=rbf; total time=  15.5s
# [CV] END ...........C=500, degree=2, gamma=scale, kernel=rbf; total time=  19.1s
# [CV] END ............C=10, degree=4, gamma=scale, kernel=rbf; total time=   9.0s
# [CV] END ...........C=500, degree=2, gamma=scale, kernel=rbf; total time=  18.0s
# [CV] END ............C=10, degree=4, gamma=scale, kernel=rbf; total time=  10.9s
# [CV] END ............C=10, degree=4, gamma=scale, kernel=rbf; total time=  10.6s
# [CV] END ............C=10, degree=4, gamma=scale, kernel=rbf; total time=  10.3s
# [CV] END ............C=10, degree=4, gamma=scale, kernel=rbf; total time=   9.3s
# [CV] END ............C=100, degree=2, gamma=auto, kernel=rbf; total time=  11.3s
# [CV] END ............C=100, degree=2, gamma=auto, kernel=rbf; total time=  11.7s
# [CV] END ............C=100, degree=2, gamma=auto, kernel=rbf; total time=  10.2s
# [CV] END ............C=100, degree=2, gamma=auto, kernel=rbf; total time=  12.9s
# [CV] END ............C=100, degree=2, gamma=auto, kernel=rbf; total time=  10.9s
# [CV] END ........C=500, degree=4, gamma=scale, kernel=linear; total time= 2.1min
# [CV] END ........C=500, degree=4, gamma=scale, kernel=linear; total time= 2.2min
# [CV] END ........C=500, degree=4, gamma=scale, kernel=linear; total time= 2.2min
# [CV] END ........C=500, degree=4, gamma=scale, kernel=linear; total time= 2.4min
# [CV] END ........C=500, degree=4, gamma=scale, kernel=linear; total time= 2.5min
# Najlepsze parametry SVC: {'kernel': 'rbf', 'gamma': 'scale', 'degree': 2, 'C': 500}

# %%
import pandas as pd
import matplotlib.pyplot as plt

# wyniki z RandomizedSearchCV
results = pd.DataFrame(search_svc.cv_results_)

# lista metryk dostępnych w wynikach
metrics = [m for m in ["mean_test_f1", "mean_test_precision", "mean_test_recall", "mean_test_precisionF"]
           if m in results.columns]

# wybieramy parametr do osi X
param_to_plot = "param_C"

# średnia metryk po wartościach parametru (C)
plot_data = results.groupby(param_to_plot)[metrics].mean().sort_index()

# wykres
plt.figure(figsize=(10, 5))
for metric in metrics:
    plt.plot(plot_data.index, plot_data[metric], marker='o', label=metric)

plt.xlabel("C")
plt.ylabel("Score")
plt.title("Średnie metryki vs parametr C w SVC")
plt.legend()
plt.grid(True)
plt.xscale("log")  # ponieważ C zwykle w log skali
plt.show()

# %% [markdown]
# Now let's try to combine them bo voting classifier

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, f1_score, precision_score, recall_score

# Załóżmy, że masz już gotowe modele:
# rf = RandomForestClassifier(...)
# svc = Pipeline([...])  # SVC w pipeline ze skalowaniem

voting_clf = VotingClassifier(
    estimators=[
        ('rf', optimal_rf),
        ('svc', optimal_svc)
    ],
    voting='soft'  # potrzebne, żeby działały wagi
)

# Parametry do strojenia: tylko wagi
param_grid = {
    'weights': [
        [1, 1],
        [2, 1],
        [1, 2],
        [3, 1],
        [1, 3],
        [4, 1],
        [5, 1],
    ]
}

# GridSearchCV
grid_search = GridSearchCV(
    estimator=voting_clf,
    param_grid=param_grid,
    cv=5,
    scoring=scoring,
    refit='precision',  # najlepszy model wg F1
    n_jobs=-1,
    verbose=2
)

grid_search.fit(X_train, y_train)

print("Best weights:", grid_search.best_params_['weights'])
# Out:
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [CV] END .....................................weights=[1, 1]; total time=  22.2s
# [CV] END .....................................weights=[2, 1]; total time=  22.2s
# [CV] END .....................................weights=[1, 1]; total time=  22.7s
# [CV] END .....................................weights=[2, 1]; total time=  23.0s
# [CV] END .....................................weights=[1, 1]; total time=  23.3s
# [CV] END .....................................weights=[2, 1]; total time=  24.2s
# [CV] END .....................................weights=[1, 1]; total time=  24.8s
# [CV] END .....................................weights=[1, 1]; total time=  27.5s
# [CV] END .....................................weights=[2, 1]; total time=  23.3s
# [CV] END .....................................weights=[1, 2]; total time=  22.5s
# [CV] END .....................................weights=[1, 2]; total time=  23.8s
# [CV] END .....................................weights=[1, 2]; total time=  24.8s
# [CV] END .....................................weights=[1, 2]; total time=  23.8s
# [CV] END .....................................weights=[2, 1]; total time=  28.1s
# [CV] END .....................................weights=[3, 1]; total time=  25.1s
# [CV] END .....................................weights=[1, 2]; total time=  29.0s
# [CV] END .....................................weights=[3, 1]; total time=  23.2s
# [CV] END .....................................weights=[3, 1]; total time=  25.8s
# [CV] END .....................................weights=[3, 1]; total time=  25.1s
# [CV] END .....................................weights=[1, 3]; total time=  25.1s
# [CV] END .....................................weights=[3, 1]; total time=  29.0s
# [CV] END .....................................weights=[1, 3]; total time=  23.0s
# [CV] END .....................................weights=[1, 3]; total time=  25.7s
# [CV] END .....................................weights=[1, 3]; total time=  28.6s
# [CV] END .....................................weights=[1, 3]; total time=  24.7s
# [CV] END .....................................weights=[4, 1]; total time=  25.2s
# [CV] END .....................................weights=[4, 1]; total time=  23.8s
# [CV] END .....................................weights=[4, 1]; total time=  27.9s
# [CV] END .....................................weights=[4, 1]; total time=  25.6s
# [CV] END .....................................weights=[5, 1]; total time=  26.0s
# [CV] END .....................................weights=[4, 1]; total time=  29.6s
# [CV] END .....................................weights=[5, 1]; total time=  27.5s
# [CV] END .....................................weights=[5, 1]; total time=  21.2s
# [CV] END .....................................weights=[5, 1]; total time=  19.4s
# [CV] END .....................................weights=[5, 1]; total time=  22.1s
# Best weights: [4, 1]

# %%
optimal_voting_rf_svc = grid_search.best_estimator_
print(results[["params", "mean_test_f1", "mean_test_precision", "mean_test_recall"]])
from sklearn.metrics import confusion_matrix
best_cm = confusion_matrix(y_test, optimal_voting_rf_svc.predict(X_test))
tree_cm = confusion_matrix(y_test, optimal_rf.predict(X_test))
print("Macierz pomyłek voting:\n", best_cm)
print("Macierz pomyłek randForest:\n", best_cm)
# Out:
#                                                params  mean_test_f1  \
# 0   {'kernel': 'linear', 'gamma': 'scale', 'degree...      0.735190
# 1   {'kernel': 'linear', 'gamma': 'auto', 'degree'...      0.766522
# 2   {'kernel': 'linear', 'gamma': 'auto', 'degree'...      0.734717
# 3   {'kernel': 'linear', 'gamma': 'scale', 'degree...      0.735190
# 4   {'kernel': 'linear', 'gamma': 'scale', 'degree...      0.760335
# 5   {'kernel': 'linear', 'gamma': 'auto', 'degree'...      0.766673
# 6   {'kernel': 'linear', 'gamma': 'auto', 'degree'...      0.735190
# 7   {'kernel': 'linear', 'gamma': 'auto', 'degree'...      0.760335
# 8   {'kernel': 'linear', 'gamma': 'scale', 'degree...      0.734717
# 9   {'kernel': 'linear', 'gamma': 'auto', 'degree'...      0.766673
# 10  {'kernel': 'rbf', 'gamma': 'auto', 'degree': 4...      0.773776
# 11  {'kernel': 'rbf', 'gamma': 'auto', 'degree': 3...      0.747105
# 12  {'kernel': 'rbf', 'gamma': 'scale', 'degree': ...      0.737533
# 13  {'kernel': 'rbf', 'gamma': 'scale', 'degree': ...      0.773705
# 14  {'kernel': 'rbf', 'gamma': 'scale', 'degree': ...      0.737533
# 15  {'kernel': 'linear', 'gamma': 'auto', 'degree'...      0.734717
# 16  {'kernel': 'linear', 'gamma': 'scale', 'degree...      0.766673
# 17  {'kernel': 'rbf', 'gamma': 'scale', 'degree': ...      0.784231
# 18  {'kernel': 'rbf', 'gamma': 'scale', 'degree': ...      0.745622
# 19  {'kernel': 'rbf', 'gamma': 'auto', 'degree': 2...      0.773776
#
#     mean_test_precision  mean_test_recall
# 0              0.648446          0.854489
# 1              0.711887          0.841692
# 2              0.668982          0.821259
# 3              0.648446          0.854489
# 4              0.700050          0.841692
# 5              0.711719          0.842105
# 6              0.648446          0.854489
# 7              0.700050          0.841692
# 8              0.668982          0.821259
# 9              0.711719          0.842105
# 10             0.741837          0.820227
# 11             0.704073          0.804954
# 12             0.645476          0.865635
# 13             0.741487          0.820640
# 14             0.645476          0.865635
# 15             0.668982          0.821259
# 16             0.711719          0.842105
# 17             0.749958          0.835501
# 18             0.703780          0.802683
# 19             0.741837          0.820227
# Macierz pomyłek voting:
#  [[1031  218]
#  [ 235 1164]]
# Macierz pomyłek randForest:
#  [[1031  218]
#  [ 235 1164]]

# %% [markdown]
# Now we'll try tu dumb everything to files and try to work with thresholds on a new file

# %%
from sklearn import datasets
from sklearn.ensemble import RandomForestClassifier
import joblib

joblib.dump(optimal_rf, "../../saved-models/merged/optimal_rf.pkl")
joblib.dump(optimal_svc, "../../saved-models/merged/optimal_svc.pkl")
joblib.dump(optimal_voting_rf_svc, "../../saved-models/merged/optimal_voting_rf_svc.pkl")
# Out:
# ['../../saved-models/merged/optimal_voting_rf_svc.pkl']

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import (
    confusion_matrix, ConfusionMatrixDisplay,
    precision_recall_curve, average_precision_score
)

def plot_cm_and_pr(y_true, y_proba, threshold=0.5, title="Model"):
    """
    y_true  : array-like (n,), binary labels {0,1}
    y_proba : array-like (n,), predicted probabilities for the positive class
    threshold : float in [0,1] to convert probabilities to hard labels
    title   : str, used in plot titles/legend
    """
    y_true  = np.asarray(y_true).astype(int)
    y_proba = np.asarray(y_proba).astype(float)
    y_pred  = (y_proba >= threshold).astype(int)

    # --- Confusion matrices ---
    fig, ax = plt.subplots(1, 2, figsize=(10, 4))

    cm = confusion_matrix(y_true, y_pred, labels=[0, 1])
    ConfusionMatrixDisplay(cm, display_labels=[0, 1]).plot(ax=ax[0], colorbar=False)
    ax[0].set_title(f"{title} — Confusion Matrix (θ={threshold:.2f})")
    ax[0].grid(False)

    cm_norm = confusion_matrix(y_true, y_pred, labels=[0, 1], normalize="true")
    ConfusionMatrixDisplay(cm_norm, display_labels=[0, 1]).plot(ax=ax[1], colorbar=False)
    ax[1].set_title(f"{title} — Confusion Matrix (Normalized)")
    ax[1].grid(False)

    plt.tight_layout()
    plt.show()

    # --- Precision–Recall curve & PR-AUC ---
    precision, recall, _ = precision_recall_curve(y_true, y_proba)
    ap = average_precision_score(y_true, y_proba)
    baseline = y_true.mean()  # positive rate

    plt.figure(figsize=(6, 4))
    plt.plot(recall, precision, lw=2, label=f"{title} (AP={ap:.3f})")
    plt.hlines(baseline, 0, 1, colors="gray", linestyles="--",
               label=f"Baseline (pos rate={baseline:.3f})", alpha=0.7)
    plt.xlim(0, 1); plt.ylim(0, 1.01)
    plt.xlabel("Recall")
    plt.ylabel("Precision")
    plt.title(f"{title} — Precision–Recall Curve")
    plt.grid(True, linestyle=":")
    plt.legend()
    plt.show()

    print(f"PR-AUC (Average Precision): {ap:.4f}")
