# %% [markdown]
# ## Testing models with merged data from Nasa

# %% [markdown]
# With the merged data, now we'll try some typical models for our ML

# %%
from sklearn.metrics import make_scorer, precision_score, f1_score, recall_score
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
import pandas as pd
from sklearn.ensemble import RandomForestClassifier

X_train = pd.read_csv("../../datasets/merged/X_train_imputed_scaled.csv", index_col=0)
X_test = pd.read_csv("../../datasets/merged/X_test_imputed_scaled.csv",  index_col=0)
y_train = pd.read_csv("../../datasets/merged/y_train.csv", index_col=0)["label"]
y_test = pd.read_csv("../../datasets/merged/y_test.csv",  index_col=0)["label"]
groups = pd.read_csv("../../datasets/merged/groups.csv", index_col=0)["star_key"]

param_grid = {
    'n_estimators': [50, 100, 150, 200, 300],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2],
    'max_features': ['sqrt', 'log2'],
    'criterion': ['gini', 'entropy']
}

rf = RandomForestClassifier(random_state=42)

scoring = {
    "f1": make_scorer(f1_score, pos_label= 1),
    "precision": make_scorer(precision_score, pos_label= 1),
    "recall": make_scorer(recall_score, pos_label=1),
    "precisionF" : make_scorer(precision_score, pos_label=0),
}

search_rf = RandomizedSearchCV(
    rf,
    param_distributions=param_grid,
    n_iter=50,
    cv=5,
    n_jobs=-1,
    random_state=42,
    verbose=2,
    scoring=scoring,
    refit='precision'
)


search_rf.fit(X_train, y_train)
print(search_rf.best_params_)
optimal_rf = search_rf.best_estimator_
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.4s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.5s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.5s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.6s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.7s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.9s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.0s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.1s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.1s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.4s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   4.4s
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   4.5s
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   4.6s
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   4.7s
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   4.9s
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   5.2s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   2.1s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   4.6s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   4.7s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   4.6s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   2.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   2.1s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   4.9s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=   5.1s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   2.1s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   2.4s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   4.7s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   4.6s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.5s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.5s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.5s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   4.9s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.6s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   5.1s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.8s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.7s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.6s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 43
#      23 scoring = {
#      24     "f1": make_scorer(f1_score, pos_label= 1),
#      25     "precision": make_scorer(precision_score, pos_label= 1),
#      26     "recall": make_scorer(recall_score, pos_label=1),
#      27     "precisionF" : make_scorer(precision_score, pos_label=0),
#      28 }
#      30 search_rf = RandomizedSearchCV(
#      31     rf,
#      32     param_distributions=param_grid,
#    (...)     39     refit='precision'
#      40 )
# ---> 43 search_rf.fit(X_train, y_train)
#      44 print(search_rf.best_params_)
#      45 optimal_rf = search_rf.best_estimator_
#
# File ~/PycharmProjects/SpaceAppsExoplanets/.venv/lib/python3.12/site-packages/sklearn/base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~/PycharmProjects/SpaceAppsExoplanets/.venv/lib/python3.12/site-packages/sklearn/model_selection/_search.py:1051, in BaseSearchCV.fit(self, X, y, **params)
#    1045     results = self._format_results(
#    1046         all_candidate_params, n_splits, all_out, all_more_results
#    1047     )
#    1049     return results
# -> 1051 self._run_search(evaluate_candidates)
#    1053 # multimetric is determined here because in the case of a callable
#    1054 # self.scoring the return type is only known after calling
#    1055 first_test_score = all_out[0]["test_scores"]
#
# File ~/PycharmProjects/SpaceAppsExoplanets/.venv/lib/python3.12/site-packages/sklearn/model_selection/_search.py:1992, in RandomizedSearchCV._run_search(self, evaluate_candidates)
#    1990 def _run_search(self, evaluate_candidates):
#    1991     """Search n_iter candidates from param_distributions"""
# -> 1992     evaluate_candidates(
#    1993         ParameterSampler(
#    1994             self.param_distributions, self.n_iter, random_state=self.random_state
#    1995         )
#    1996     )
#
# File ~/PycharmProjects/SpaceAppsExoplanets/.venv/lib/python3.12/site-packages/sklearn/model_selection/_search.py:997, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     989 if self.verbose > 0:
#     990     print(
#     991         "Fitting {0} folds for each of {1} candidates,"
#     992         " totalling {2} fits".format(
#     993             n_splits, n_candidates, n_candidates * n_splits
#     994         )
#     995     )
# --> 997 out = parallel(
#     998     delayed(_fit_and_score)(
#     999         clone(base_estimator),
#    1000         X,
#    1001         y,
#    1002         train=train,
#    1003         test=test,
#    1004         parameters=parameters,
#    1005         split_progress=(split_idx, n_splits),
#    1006         candidate_progress=(cand_idx, n_candidates),
#    1007         **fit_and_score_kwargs,
#    1008     )
#    1009     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#    1010         enumerate(candidate_params),
#    1011         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#    1012     )
#    1013 )
#    1015 if len(out) < 1:
#    1016     raise ValueError(
#    1017         "No fits were performed. "
#    1018         "Was the CV iterator empty? "
#    1019         "Were there no candidates?"
#    1020     )
#
# File ~/PycharmProjects/SpaceAppsExoplanets/.venv/lib/python3.12/site-packages/sklearn/utils/parallel.py:82, in Parallel.__call__(self, iterable)
#      73 warning_filters = warnings.filters
#      74 iterable_with_config_and_warning_filters = (
#      75     (
#      76         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     80     for delayed_func, args, kwargs in iterable
#      81 )
# ---> 82 return super().__call__(iterable_with_config_and_warning_filters)
#
# File ~/PycharmProjects/SpaceAppsExoplanets/.venv/lib/python3.12/site-packages/joblib/parallel.py:2072, in Parallel.__call__(self, iterable)
#    2066 # The first item from the output is blank, but it makes the interpreter
#    2067 # progress until it enters the Try/Except block of the generator and
#    2068 # reaches the first `yield` statement. This starts the asynchronous
#    2069 # dispatch of the tasks to the workers.
#    2070 next(output)
# -> 2072 return output if self.return_generator else list(output)
#
# File ~/PycharmProjects/SpaceAppsExoplanets/.venv/lib/python3.12/site-packages/joblib/parallel.py:1682, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1679     yield
#    1681     with self._backend.retrieval_context():
# -> 1682         yield from self._retrieve()
#    1684 except GeneratorExit:
#    1685     # The generator has been garbage collected before being fully
#    1686     # consumed. This aborts the remaining tasks if possible and warn
#    1687     # the user if necessary.
#    1688     self._exception = True
#
# File ~/PycharmProjects/SpaceAppsExoplanets/.venv/lib/python3.12/site-packages/joblib/parallel.py:1800, in Parallel._retrieve(self)
#    1789 if self.return_ordered:
#    1790     # Case ordered: wait for completion (or error) of the next job
#    1791     # that have been dispatched and not retrieved yet. If no job
#    (...)   1795     # control only have to be done on the amount of time the next
#    1796     # dispatched job is pending.
#    1797     if (nb_jobs == 0) or (
#    1798         self._jobs[0].get_status(timeout=self.timeout) == TASK_PENDING
#    1799     ):
# -> 1800         time.sleep(0.01)
#    1801         continue
#    1803 elif nb_jobs == 0:
#    1804     # Case unordered: jobs are added to the list of jobs to
#    1805     # retrieve `self._jobs` only once completed or in error, which
#    (...)   1811     # timeouts before any other dispatched job has completed and
#    1812     # been added to `self._jobs` to be retrieved.
#
# KeyboardInterrupt:

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Wyniki z grid searcha
results = pd.DataFrame(search_rf.cv_results_)  # search = RandomizedSearchCV

# Wybieramy kolumnę parametru, który chcemy analizować (np. n_estimators)
# Dla pipeline byłoby "param_classifier__n_estimators", ale u Ciebie raczej sam model:
results = results.set_index("param_n_estimators")

# Wybieramy metryki, które nas interesują
metrics = ["mean_test_f1", "mean_test_precision", "mean_test_recall", "mean_test_precisionF"]

# Tworzymy podzbiór danych
plot_data = results.groupby("param_n_estimators")[metrics].mean()

# --- Rysowanie wykresu ---
plt.figure(figsize=(10, 5))
for metric in metrics:
    plt.plot(plot_data.index, plot_data[metric], marker='o', label=metric)

plt.xlabel("n_estimators")
plt.ylabel("Score")
plt.title("Metryki vs liczba drzew w RandomForestClassifier")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Now we will try SVC

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
svc = SVC(probability=True)

param_grid = {
    "C": [0.1, 1, 10, 100, 500, 1000,],
    "kernel": ["linear", "rbf"],
    "gamma": ["scale", "auto"],  # tylko dla rbf
    "degree": [2, 3, 4],         # tylko dla poly / linear, dla rbf nie używa się
}

search_svc = RandomizedSearchCV(
    estimator=svc,
    param_distributions=param_grid,
    n_iter=20,           # losowe kombinacje
    cv=5,
    n_jobs=-1,
    verbose=2,
    random_state=42,
    scoring=scoring,
    refit="f1"
)

search_svc.fit(X_train, y_train)

print("Najlepsze parametry SVC:", search_svc.best_params_)
optimal_svc = search_svc.best_estimator_
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV] END ........C=0.1, degree=3, gamma=scale, kernel=linear; total time=   5.5s
# [CV] END ........C=0.1, degree=2, gamma=scale, kernel=linear; total time=   5.8s
# [CV] END ........C=0.1, degree=3, gamma=scale, kernel=linear; total time=   5.9s
# [CV] END ........C=0.1, degree=3, gamma=scale, kernel=linear; total time=   5.9s
# [CV] END ........C=0.1, degree=3, gamma=scale, kernel=linear; total time=   6.1s
# [CV] END ........C=0.1, degree=3, gamma=scale, kernel=linear; total time=   6.3s
# [CV] END ...........C=1, degree=3, gamma=auto, kernel=linear; total time=   6.9s
# [CV] END ...........C=1, degree=3, gamma=auto, kernel=linear; total time=   7.0s
# [CV] END ...........C=1, degree=3, gamma=auto, kernel=linear; total time=   7.3s
# [CV] END ...........C=1, degree=3, gamma=auto, kernel=linear; total time=   7.4s
# [CV] END ...........C=1, degree=3, gamma=auto, kernel=linear; total time=   8.0s
# [CV] END ........C=0.1, degree=2, gamma=scale, kernel=linear; total time=   6.1s
# [CV] END ........C=0.1, degree=2, gamma=scale, kernel=linear; total time=   6.0s
# [CV] END ........C=0.1, degree=2, gamma=scale, kernel=linear; total time=   6.1s
# [CV] END ........C=0.1, degree=2, gamma=scale, kernel=linear; total time=   6.3s
# [CV] END .........C=0.1, degree=4, gamma=auto, kernel=linear; total time=   6.8s
# [CV] END .........C=10, degree=3, gamma=scale, kernel=linear; total time=  13.4s
# [CV] END .........C=10, degree=3, gamma=scale, kernel=linear; total time=  14.1s
# [CV] END .........C=10, degree=3, gamma=scale, kernel=linear; total time=  15.4s
# [CV] END .........C=10, degree=3, gamma=scale, kernel=linear; total time=  16.7s
# [CV] END .........C=10, degree=3, gamma=scale, kernel=linear; total time=  15.9s
# [CV] END .........C=0.1, degree=4, gamma=auto, kernel=linear; total time=   6.5s
# [CV] END .........C=0.1, degree=4, gamma=auto, kernel=linear; total time=   5.9s
# [CV] END .........C=0.1, degree=4, gamma=auto, kernel=linear; total time=   6.4s
# [CV] END .........C=0.1, degree=4, gamma=auto, kernel=linear; total time=   6.3s
# [CV] END ..........C=1, degree=2, gamma=scale, kernel=linear; total time=   8.0s
# [CV] END ..........C=10, degree=4, gamma=auto, kernel=linear; total time=  15.7s
# [CV] END ..........C=10, degree=4, gamma=auto, kernel=linear; total time=  15.9s
# [CV] END ..........C=10, degree=4, gamma=auto, kernel=linear; total time=  14.4s
# [CV] END ..........C=10, degree=4, gamma=auto, kernel=linear; total time=  13.7s
# [CV] END ..........C=10, degree=4, gamma=auto, kernel=linear; total time=  14.7s
# [CV] END ..........C=1, degree=2, gamma=scale, kernel=linear; total time=   8.0s
# [CV] END ..........C=1, degree=2, gamma=scale, kernel=linear; total time=   8.1s
# [CV] END ..........C=1, degree=2, gamma=scale, kernel=linear; total time=   8.3s
# [CV] END ..........C=1, degree=2, gamma=scale, kernel=linear; total time=   7.5s
# [CV] END ............C=100, degree=4, gamma=auto, kernel=rbf; total time=  11.9s
# [CV] END ............C=100, degree=4, gamma=auto, kernel=rbf; total time=  12.0s
# [CV] END ............C=100, degree=4, gamma=auto, kernel=rbf; total time=  10.9s
# [CV] END ............C=100, degree=4, gamma=auto, kernel=rbf; total time=  12.9s
# [CV] END ............C=100, degree=4, gamma=auto, kernel=rbf; total time=  11.2s
# [CV] END .............C=10, degree=3, gamma=auto, kernel=rbf; total time=  10.3s
# [CV] END .............C=10, degree=3, gamma=auto, kernel=rbf; total time=  10.3s
# [CV] END .............C=10, degree=3, gamma=auto, kernel=rbf; total time=  10.0s
# [CV] END .............C=10, degree=3, gamma=auto, kernel=rbf; total time=  10.6s
# [CV] END .............C=10, degree=3, gamma=auto, kernel=rbf; total time=  10.3s
# [CV] END .........C=500, degree=2, gamma=auto, kernel=linear; total time= 2.4min
# [CV] END .........C=500, degree=2, gamma=auto, kernel=linear; total time= 2.6min
# [CV] END .........C=500, degree=2, gamma=auto, kernel=linear; total time= 2.6min
# [CV] END ...........C=0.1, degree=4, gamma=scale, kernel=rbf; total time=  11.0s
# [CV] END ...........C=0.1, degree=4, gamma=scale, kernel=rbf; total time=  11.4s
# [CV] END ...........C=0.1, degree=4, gamma=scale, kernel=rbf; total time=  10.9s
# [CV] END .........C=500, degree=2, gamma=auto, kernel=linear; total time= 2.8min
# [CV] END ...........C=0.1, degree=4, gamma=scale, kernel=rbf; total time=  11.7s
# [CV] END ...........C=0.1, degree=4, gamma=scale, kernel=rbf; total time=  10.4s
# [CV] END ...........C=100, degree=4, gamma=scale, kernel=rbf; total time=  12.5s
# [CV] END .........C=500, degree=2, gamma=auto, kernel=linear; total time= 2.9min
# [CV] END ...........C=100, degree=4, gamma=scale, kernel=rbf; total time=  11.6s
# [CV] END ...........C=100, degree=4, gamma=scale, kernel=rbf; total time=  13.2s
# [CV] END ...........C=100, degree=4, gamma=scale, kernel=rbf; total time=  12.2s
# [CV] END ...........C=100, degree=4, gamma=scale, kernel=rbf; total time=  13.7s
# [CV] END .........C=500, degree=3, gamma=auto, kernel=linear; total time= 2.4min
# [CV] END ...........C=0.1, degree=3, gamma=scale, kernel=rbf; total time=  11.4s
# [CV] END ...........C=0.1, degree=3, gamma=scale, kernel=rbf; total time=  11.4s
# [CV] END .........C=500, degree=3, gamma=auto, kernel=linear; total time= 2.5min
# [CV] END ...........C=1, degree=4, gamma=auto, kernel=linear; total time=   7.7s
# [CV] END ...........C=1, degree=4, gamma=auto, kernel=linear; total time=   8.3s
# [CV] END ...........C=0.1, degree=3, gamma=scale, kernel=rbf; total time=  11.7s
# [CV] END ...........C=0.1, degree=3, gamma=scale, kernel=rbf; total time=  11.8s
# [CV] END ...........C=1, degree=4, gamma=auto, kernel=linear; total time=   7.7s
# [CV] END ...........C=1, degree=4, gamma=auto, kernel=linear; total time=   8.0s
# [CV] END ...........C=0.1, degree=3, gamma=scale, kernel=rbf; total time=  10.4s
# [CV] END .........C=500, degree=3, gamma=auto, kernel=linear; total time= 2.6min
# [CV] END ...........C=1, degree=4, gamma=auto, kernel=linear; total time=   7.8s
# [CV] END ...........C=500, degree=2, gamma=scale, kernel=rbf; total time=  18.2s
# [CV] END .........C=500, degree=3, gamma=auto, kernel=linear; total time= 3.0min
# [CV] END ...........C=500, degree=2, gamma=scale, kernel=rbf; total time=  18.0s
# [CV] END ...........C=500, degree=2, gamma=scale, kernel=rbf; total time=  20.1s
# [CV] END .........C=500, degree=3, gamma=auto, kernel=linear; total time= 3.1min
# [CV] END ...........C=500, degree=2, gamma=scale, kernel=rbf; total time=  22.6s
# [CV] END ............C=10, degree=4, gamma=scale, kernel=rbf; total time=  10.7s
# [CV] END ............C=10, degree=4, gamma=scale, kernel=rbf; total time=  10.9s
# [CV] END ............C=10, degree=4, gamma=scale, kernel=rbf; total time=   9.9s
# [CV] END ...........C=500, degree=2, gamma=scale, kernel=rbf; total time=  18.1s
# [CV] END ............C=10, degree=4, gamma=scale, kernel=rbf; total time=  11.0s
# [CV] END ............C=10, degree=4, gamma=scale, kernel=rbf; total time=  11.0s
# [CV] END ............C=100, degree=2, gamma=auto, kernel=rbf; total time=  12.3s
# [CV] END ............C=100, degree=2, gamma=auto, kernel=rbf; total time=  11.2s
# [CV] END ............C=100, degree=2, gamma=auto, kernel=rbf; total time=  12.6s
# [CV] END ............C=100, degree=2, gamma=auto, kernel=rbf; total time=   8.7s
# [CV] END ............C=100, degree=2, gamma=auto, kernel=rbf; total time=  12.7s
# [CV] END ........C=1000, degree=2, gamma=auto, kernel=linear; total time= 4.3min
# [CV] END ........C=1000, degree=2, gamma=auto, kernel=linear; total time= 4.4min
# [CV] END ........C=1000, degree=2, gamma=auto, kernel=linear; total time= 4.4min
# [CV] END ........C=1000, degree=2, gamma=auto, kernel=linear; total time= 4.9min
# [CV] END ........C=1000, degree=2, gamma=auto, kernel=linear; total time= 4.9min
# [CV] END ........C=500, degree=4, gamma=scale, kernel=linear; total time= 1.7min
# [CV] END ........C=500, degree=4, gamma=scale, kernel=linear; total time= 1.8min
# [CV] END ........C=500, degree=4, gamma=scale, kernel=linear; total time= 1.8min
# [CV] END ........C=500, degree=4, gamma=scale, kernel=linear; total time= 1.9min
# [CV] END ........C=500, degree=4, gamma=scale, kernel=linear; total time= 2.1min
# Najlepsze parametry SVC: {'kernel': 'rbf', 'gamma': 'scale', 'degree': 2, 'C': 500}

# %%
import pandas as pd
import matplotlib.pyplot as plt

# wyniki z RandomizedSearchCV
results = pd.DataFrame(search_svc.cv_results_)

# lista metryk dostępnych w wynikach
metrics = [m for m in ["mean_test_f1", "mean_test_precision", "mean_test_recall", "mean_test_precisionF"]
           if m in results.columns]

# wybieramy parametr do osi X
param_to_plot = "param_C"

# średnia metryk po wartościach parametru (C)
plot_data = results.groupby(param_to_plot)[metrics].mean().sort_index()

# wykres
plt.figure(figsize=(10, 5))
for metric in metrics:
    plt.plot(plot_data.index, plot_data[metric], marker='o', label=metric)

plt.xlabel("C")
plt.ylabel("Score")
plt.title("Średnie metryki vs parametr C w SVC")
plt.legend()
plt.grid(True)
plt.xscale("log")  # ponieważ C zwykle w log skali
plt.show()

# %% [markdown]
# Now let's try to combine them bo voting classifier

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, f1_score, precision_score, recall_score

# Załóżmy, że masz już gotowe modele:
# rf = RandomForestClassifier(...)
# svc = Pipeline([...])  # SVC w pipeline ze skalowaniem

voting_clf = VotingClassifier(
    estimators=[
        ('rf', optimal_rf),
        ('svc', optimal_svc)
    ],
    voting='soft'  # potrzebne, żeby działały wagi
)

# Parametry do strojenia: tylko wagi
param_grid = {
    'weights': [
        [1, 1],
        [2, 1],
        [1, 2],
        [3, 1],
        [1, 3],
        [4, 1],
        [5, 1],
    ]
}

# GridSearchCV
grid_search = GridSearchCV(
    estimator=voting_clf,
    param_grid=param_grid,
    cv=5,
    scoring=scoring,
    refit='precision',  # najlepszy model wg F1
    n_jobs=-1,
    verbose=2
)

grid_search.fit(X_train, y_train)

print("Best weights:", grid_search.best_params_['weights'])
# Out:
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [CV] END .....................................weights=[1, 2]; total time=  15.7s
# [CV] END .....................................weights=[2, 1]; total time=  16.7s
# [CV] END .....................................weights=[1, 1]; total time=  17.2s
# [CV] END .....................................weights=[2, 1]; total time=  17.6s
# [CV] END .....................................weights=[1, 1]; total time=  17.6s
# [CV] END .....................................weights=[2, 1]; total time=  17.7s
# [CV] END .....................................weights=[1, 2]; total time=  17.9s
# [CV] END .....................................weights=[1, 2]; total time=  18.2s
# [CV] END .....................................weights=[1, 1]; total time=  18.3s
# [CV] END .....................................weights=[2, 1]; total time=  18.6s
# [CV] END .....................................weights=[3, 1]; total time=  18.5s
# [CV] END .....................................weights=[1, 1]; total time=  19.6s
# [CV] END .....................................weights=[1, 2]; total time=  19.8s
# [CV] END .....................................weights=[2, 1]; total time=  21.5s
# [CV] END .....................................weights=[1, 1]; total time=  22.1s
# [CV] END .....................................weights=[1, 2]; total time=  22.9s
# [CV] END .....................................weights=[3, 1]; total time=  17.6s
# [CV] END .....................................weights=[3, 1]; total time=  19.5s
# [CV] END .....................................weights=[1, 3]; total time=  18.3s
# [CV] END .....................................weights=[3, 1]; total time=  18.4s
# [CV] END .....................................weights=[1, 3]; total time=  18.3s
# [CV] END .....................................weights=[4, 1]; total time=  16.9s
# [CV] END .....................................weights=[1, 3]; total time=  18.5s
# [CV] END .....................................weights=[4, 1]; total time=  18.9s
# [CV] END .....................................weights=[1, 3]; total time=  20.0s
# [CV] END .....................................weights=[3, 1]; total time=  21.2s
# [CV] END .....................................weights=[4, 1]; total time=  17.2s
# [CV] END .....................................weights=[4, 1]; total time=  20.5s
# [CV] END .....................................weights=[5, 1]; total time=  17.7s
# [CV] END .....................................weights=[4, 1]; total time=  20.0s
# [CV] END .....................................weights=[1, 3]; total time=  21.7s
# [CV] END .....................................weights=[5, 1]; total time=  17.9s
# [CV] END .....................................weights=[5, 1]; total time=  10.1s
# [CV] END .....................................weights=[5, 1]; total time=  10.0s
# [CV] END .....................................weights=[5, 1]; total time=  11.9s
# Best weights: [5, 1]

# %%
optimal_voting_rf_svc = grid_search.best_estimator_
print(results[["params", "mean_test_f1", "mean_test_precision", "mean_test_recall"]])
from sklearn.metrics import confusion_matrix
best_cm = confusion_matrix(y_test, optimal_voting_rf_svc.predict(X_test))
tree_cm = confusion_matrix(y_test, optimal_rf.predict(X_test))
print("Macierz pomyłek voting:\n", best_cm)
print("Macierz pomyłek randForest:\n", best_cm)
# Out:
#                                                                params  \
# param_n_estimators
# 300                 {'n_estimators': 300, 'min_samples_split': 2, ...
# 100                 {'n_estimators': 100, 'min_samples_split': 5, ...
# 200                 {'n_estimators': 200, 'min_samples_split': 2, ...
# 300                 {'n_estimators': 300, 'min_samples_split': 5, ...
# 300                 {'n_estimators': 300, 'min_samples_split': 2, ...
# 150                 {'n_estimators': 150, 'min_samples_split': 2, ...
# 200                 {'n_estimators': 200, 'min_samples_split': 2, ...
# 100                 {'n_estimators': 100, 'min_samples_split': 5, ...
# 300                 {'n_estimators': 300, 'min_samples_split': 5, ...
# 200                 {'n_estimators': 200, 'min_samples_split': 2, ...
# 50                  {'n_estimators': 50, 'min_samples_split': 5, '...
# 100                 {'n_estimators': 100, 'min_samples_split': 5, ...
# 300                 {'n_estimators': 300, 'min_samples_split': 2, ...
# 200                 {'n_estimators': 200, 'min_samples_split': 5, ...
# 200                 {'n_estimators': 200, 'min_samples_split': 2, ...
# 50                  {'n_estimators': 50, 'min_samples_split': 2, '...
# 50                  {'n_estimators': 50, 'min_samples_split': 5, '...
# 50                  {'n_estimators': 50, 'min_samples_split': 5, '...
# 150                 {'n_estimators': 150, 'min_samples_split': 2, ...
# 50                  {'n_estimators': 50, 'min_samples_split': 5, '...
# 150                 {'n_estimators': 150, 'min_samples_split': 5, ...
# 300                 {'n_estimators': 300, 'min_samples_split': 5, ...
# 50                  {'n_estimators': 50, 'min_samples_split': 5, '...
# 50                  {'n_estimators': 50, 'min_samples_split': 2, '...
# 100                 {'n_estimators': 100, 'min_samples_split': 5, ...
# 50                  {'n_estimators': 50, 'min_samples_split': 2, '...
# 50                  {'n_estimators': 50, 'min_samples_split': 2, '...
# 100                 {'n_estimators': 100, 'min_samples_split': 2, ...
# 150                 {'n_estimators': 150, 'min_samples_split': 5, ...
# 200                 {'n_estimators': 200, 'min_samples_split': 2, ...
# 100                 {'n_estimators': 100, 'min_samples_split': 5, ...
# 200                 {'n_estimators': 200, 'min_samples_split': 5, ...
# 50                  {'n_estimators': 50, 'min_samples_split': 5, '...
# 150                 {'n_estimators': 150, 'min_samples_split': 2, ...
# 200                 {'n_estimators': 200, 'min_samples_split': 5, ...
# 300                 {'n_estimators': 300, 'min_samples_split': 5, ...
# 150                 {'n_estimators': 150, 'min_samples_split': 2, ...
# 50                  {'n_estimators': 50, 'min_samples_split': 5, '...
# 300                 {'n_estimators': 300, 'min_samples_split': 5, ...
# 50                  {'n_estimators': 50, 'min_samples_split': 5, '...
# 150                 {'n_estimators': 150, 'min_samples_split': 5, ...
# 150                 {'n_estimators': 150, 'min_samples_split': 2, ...
# 100                 {'n_estimators': 100, 'min_samples_split': 2, ...
# 100                 {'n_estimators': 100, 'min_samples_split': 5, ...
# 100                 {'n_estimators': 100, 'min_samples_split': 5, ...
# 100                 {'n_estimators': 100, 'min_samples_split': 5, ...
# 50                  {'n_estimators': 50, 'min_samples_split': 5, '...
# 200                 {'n_estimators': 200, 'min_samples_split': 5, ...
# 300                 {'n_estimators': 300, 'min_samples_split': 5, ...
# 50                  {'n_estimators': 50, 'min_samples_split': 2, '...
#
#                     mean_test_f1  mean_test_precision  mean_test_recall
# param_n_estimators
# 300                     0.813974             0.808351          0.840454
# 100                     0.814486             0.808770          0.841073
# 200                     0.815678             0.810170          0.841692
# 300                     0.815784             0.807925          0.844788
# 300                     0.816551             0.805631          0.848091
# 150                     0.816776             0.787663          0.866254
# 200                     0.818167             0.808396          0.848297
# 100                     0.817299             0.808702          0.846440
# 300                     0.813511             0.807204          0.840660
# 200                     0.815842             0.807738          0.844376
# 50                      0.813347             0.788518          0.859443
# 100                     0.817892             0.807452          0.848916
# 300                     0.815570             0.810231          0.840867
# 200                     0.814311             0.785404          0.864396
# 200                     0.815678             0.810170          0.841692
# 50                      0.818497             0.807732          0.848710
# 50                      0.815035             0.785746          0.864603
# 50                      0.812142             0.810387          0.834469
# 150                     0.816933             0.810757          0.843344
# 50                      0.816385             0.808820          0.843550
# 150                     0.815248             0.808313          0.842312
# 300                     0.815769             0.811102          0.840867
# 50                      0.818717             0.810480          0.847059
# 50                      0.816855             0.814026          0.839009
# 100                     0.815307             0.786161          0.865222
# 50                      0.818620             0.812729          0.842931
# 50                      0.816855             0.814026          0.839009
# 100                     0.817628             0.806864          0.849536
# 150                     0.819343             0.810341          0.848091
# 200                     0.817280             0.810766          0.843550
# 100                     0.815870             0.809749          0.842518
# 200                     0.818022             0.807014          0.849329
# 50                      0.813043             0.809216          0.837358
# 150                     0.817401             0.786805          0.868731
# 200                     0.815567             0.810112          0.841280
# 300                     0.815486             0.788950          0.862332
# 150                     0.816776             0.787663          0.866254
# 50                      0.815142             0.789777          0.860268
# 300                     0.815557             0.790072          0.861300
# 50                      0.814994             0.786220          0.863983
# 150                     0.818188             0.807508          0.849536
# 150                     0.815512             0.810450          0.841280
# 100                     0.817628             0.806864          0.849536
# 100                     0.815400             0.811681          0.839009
# 100                     0.818277             0.813539          0.843550
# 100                     0.814083             0.789399          0.859443
# 50                      0.815035             0.785746          0.864603
# 200                     0.815567             0.810112          0.841280
# 300                     0.817676             0.811522          0.844169
# 50                      0.813291             0.786622          0.860268
# Macierz pomyłek voting:
#  [[1101  148]
#  [ 421  978]]
# Macierz pomyłek randForest:
#  [[1101  148]
#  [ 421  978]]

# %% [markdown]
# Now we'll try tu dumb everything to files and try to work with thresholds on a new file

# %%
from sklearn import datasets
from sklearn.ensemble import RandomForestClassifier
import joblib

joblib.dump(optimal_rf, "../../saved-models/merged/optimal_rf.pkl")
joblib.dump(optimal_svc, "../../saved-models/merged/optimal_svc.pkl")
joblib.dump(optimal_voting_rf_svc, "../../saved-models/merged/optimal_voting_rf_svc.pkl")
# Out:
# ['optimal_voting_rf_svc.pkl']
