# %%
import pandas as pd
from sklearn.model_selection import StratifiedGroupKFold, cross_validate
from sklearn.linear_model import LogisticRegression

# Load the data
X_train = pd.read_csv("/Users/janma/Desktop/SpaceAppsExoplanets/src/backend_models/datasets/merged/X_train_imputed_scaled.csv", index_col=0)
X_test = pd.read_csv("/Users/janma/Desktop/SpaceAppsExoplanets/src/backend_models/datasets/merged/X_test_imputed_scaled.csv",  index_col=0)
y_train = pd.read_csv("/Users/janma/Desktop/SpaceAppsExoplanets/src/backend_models/datasets/merged/y_train.csv", index_col=0)["label"]
y_test = pd.read_csv("/Users/janma/Desktop/SpaceAppsExoplanets/src/backend_models/datasets/merged/y_test.csv",  index_col=0)["label"]
groups = pd.read_csv("/Users/janma/Desktop/SpaceAppsExoplanets/src/backend_models/datasets/merged/groups.csv", index_col=0)["star_key"] # "kepid" for Kepler

# Exemplary pipeline with a model
kf = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=42)
log = LogisticRegression()
score = cross_validate(log, X_train, y_train, cv=kf, scoring=["f1","roc_auc","average_precision"], n_jobs=-1, groups=groups)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 15
#      13 kf = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=42)
#      14 log = LogisticRegression()
# ---> 15 score = cross_validate(log, X_train, y_train, cv=kf, scoring=["f1","roc_auc","average_precision"], n_jobs=-1, groups=groups)
#
# File ~/miniconda3/lib/python3.12/site-packages/sklearn/utils/_param_validation.py:216, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
#     213             prefer_skip_nested_validation or global_skip_validation
#     214         )
#     215     ):
# --> 216         return func(*args, **kwargs)
#     217 except InvalidParameterError as e:
#     218     # When the function is just a wrapper around an estimator, we allow
# ...
